# %% [markdown]
# # ZERO → EMPIRE — Colab Sprite Factory
#
# GPU route for generating strict sprite candidates and QA evidence. This notebook does **not** promote assets to DONE automatically.

# %%
# !nvidia-smi
# !rm -rf /content/zero-to-empire
# !git clone --depth 1 https://github.com/dbrckk/zero-to-empire.git /content/zero-to-empire
# %cd /content/zero-to-empire

# %%
import os
os.environ['SPRITE_COUNT'] = '56'
# !python -u tools/sprites/colab_mass_factory.py

# %%
from google.colab import files
files.download('/content/zero-to-empire-colab-sprites.zip')
